# %% [markdown]
# Wczytanie danych csv

# %%
import sqlite3

import pandas as pd
import requests

nypd_df = pd.read_csv("/home/student/nypd-motor-vehicle-collisions.csv")
nypd_df
# Out:
# /tmp/ipykernel_28429/2314116211.py:6: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   nypd_df = pd.read_csv("/home/student/nypd-motor-vehicle-collisions.csv")#, usecols=["name", "ingredients"]
#                    ACCIDENT DATE ACCIDENT TIME    BOROUGH ZIP CODE   LATITUDE
# 0        2019-08-05T00:00:00.000         16:30     QUEENS  11434.0  40.676052  \
# 1        2019-08-27T00:00:00.000         16:02   BROOKLYN  11225.0  40.657780
# 2        2019-08-15T00:00:00.000         17:57  MANHATTAN  10002.0  40.718143
# 3        2019-08-30T00:00:00.000         21:53      BRONX  10460.0  40.840534
# 4        2019-08-06T00:00:00.000          9:45  MANHATTAN  10016.0  40.745440
# ...                          ...           ...        ...      ...        ...
# 1612173  2012-07-21T00:00:00.000         22:46   BROOKLYN  11226.0  40.651741
# 1612174  2012-07-09T00:00:00.000         16:45        NaN      NaN        NaN
# 1612175  2012-07-09T00:00:00.000         14:35        NaN      NaN  40.791492
# 1612176  2012-07-18T00:00:00.000          9:20  MANHATTAN  10024.0  40.779479
# 1612177  2012-07-12T00:00:00.000          3:10     QUEENS  11361.0  40.762501
#
#          LONGITUDE                                           LOCATION
# 0       -73.790184  {'type': 'Point', 'coordinates': [-73.790184, ...  \
# 1       -73.951096  {'type': 'Point', 'coordinates': [-73.951096, ...
# 2       -73.993835  {'type': 'Point', 'coordinates': [-73.993835, ...
# 3       -73.866610  {'type': 'Point', 'coordinates': [-73.86661, 4...
# 4       -73.975400  {'type': 'Point', 'coordinates': [-73.9754, 40...
# ...            ...                                                ...
# 1612173 -73.965241  {'type': 'Point', 'coordinates': [-73.9652409,...
# 1612174        NaN                                                NaN
# 1612175 -73.935763  {'type': 'Point', 'coordinates': [-73.935763, ...
# 1612176 -73.973573  {'type': 'Point', 'coordinates': [-73.9735729,...
# 1612177 -73.782522  {'type': 'Point', 'coordinates': [-73.7825216,...
#
#                            ON STREET NAME                 CROSS STREET NAME
# 0                                     NaN                               NaN  \
# 1                                     NaN                               NaN
# 2        CHRYSTIE STREET                                       GRAND STREET
# 3                                     NaN                               NaN
# 4        EAST 35 STREET                                            2 AVENUE
# ...                                   ...                               ...
# 1612173  PARADE PLACE                      CROOKE AVENUE
# 1612174  EDWARD L GRANT HIGHWAY            WEST 169 STREET
# 1612175                               NaN                               NaN
# 1612176  CENTRAL PARK WEST                 WEST 77 STREET
# 1612177  39 AVENUE                         203 STREET
#
#                                   OFF STREET NAME  ...
# 0        150-08    123 AVENUE                      ...  \
# 1        288       HAWTHORNE STREET                ...
# 2                                             NaN  ...
# 3        1837      EAST TREMONT AVENUE             ...
# 4                                             NaN  ...
# ...                                           ...  ...
# 1612173                                       NaN  ...
# 1612174                                       NaN  ...
# 1612175                                       NaN  ...
# 1612176                                       NaN  ...
# 1612177                                       NaN  ...
#
#           CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3
# 0                           Unspecified                            NaN  \
# 1                           Unspecified                            NaN
# 2                                   NaN                            NaN
# 3                           Unspecified                            NaN
# 4        Driver Inattention/Distraction                            NaN
# ...                                 ...                            ...
# 1612173                     Unspecified                            NaN
# 1612174                 Fatigued/Drowsy                    Unspecified
# 1612175                     Unspecified                            NaN
# 1612176                     Unspecified                    Unspecified
# 1612177                             NaN                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5
# 0                                  NaN                            NaN  \
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1612173                            NaN                            NaN
# 1612174                            NaN                            NaN
# 1612175                            NaN                            NaN
# 1612176                            NaN                            NaN
# 1612177                            NaN                            NaN
#
#          COLLISION_ID                  VEHICLE TYPE CODE 1
# 0             4184637                                Sedan  \
# 1             4195773  Station Wagon/Sport Utility Vehicle
# 2             4202457                                Sedan
# 3             4198749                                 Taxi
# 4             4183798  Station Wagon/Sport Utility Vehicle
# ...               ...                                  ...
# 1612173        147595        SPORT UTILITY / STATION WAGON
# 1612174         85220                    PASSENGER VEHICLE
# 1612175       2853431                    PASSENGER VEHICLE
# 1612176         52405        SPORT UTILITY / STATION WAGON
# 1612177        259445                    PASSENGER VEHICLE
#
#                          VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3
# 0                              Pick-up Truck                  NaN  \
# 1        Station Wagon/Sport Utility Vehicle                  NaN
# 2                                        NaN                  NaN
# 3        Station Wagon/Sport Utility Vehicle                  NaN
# 4                                       Bike                  NaN
# ...                                      ...                  ...
# 1612173                              UNKNOWN                  NaN
# 1612174                       LIVERY VEHICLE    PASSENGER VEHICLE
# 1612175                    PASSENGER VEHICLE                  NaN
# 1612176                                  VAN                  BUS
# 1612177                                  NaN                  NaN
#
#         VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                       NaN                 NaN
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
# ...                     ...                 ...
# 1612173                 NaN                 NaN
# 1612174                 NaN                 NaN
# 1612175                 NaN                 NaN
# 1612176                 NaN                 NaN
# 1612177                 NaN                 NaN
#
# [1612178 rows x 29 columns]

# %%
Unsafe_speed_selectes_data = nypd_df[
    (nypd_df['CONTRIBUTING FACTOR VEHICLE 1'] == 'Unsafe Speed')
    | (nypd_df['CONTRIBUTING FACTOR VEHICLE 2'] == 'Unsafe Speed')
    | (nypd_df['CONTRIBUTING FACTOR VEHICLE 3'] == 'Unsafe Speed')
    | (nypd_df['CONTRIBUTING FACTOR VEHICLE 4'] == 'Unsafe Speed')
    | (nypd_df['CONTRIBUTING FACTOR VEHICLE 5'] == 'Unsafe Speed')]
Unsafe_speed_selectes_data
# Out:
#                    ACCIDENT DATE ACCIDENT TIME        BOROUGH ZIP CODE
# 7        2019-08-11T00:00:00.000         22:23            NaN      NaN  \
# 14       2019-08-12T00:00:00.000         11:20         QUEENS  11420.0
# 111      2019-08-09T00:00:00.000          6:00  STATEN ISLAND  10312.0
# 190      2019-08-17T00:00:00.000          2:45            NaN      NaN
# 219      2019-08-30T00:00:00.000         17:15            NaN      NaN
# ...                          ...           ...            ...      ...
# 1608816  2012-08-10T00:00:00.000          5:45          BRONX  10461.0
# 1610213  2012-07-17T00:00:00.000          7:15          BRONX  10455.0
# 1610399  2012-07-12T00:00:00.000         12:40            NaN      NaN
# 1610625  2012-07-01T00:00:00.000          3:50      MANHATTAN  10014.0
# 1610834  2012-07-20T00:00:00.000         21:15      MANHATTAN  10018.0
#
#           LATITUDE  LONGITUDE
# 7        40.858210 -73.916790  \
# 14       40.678550 -73.814220
# 111      40.531110 -74.157234
# 190      40.814266 -73.912964
# 219      40.866062 -73.922510
# ...            ...        ...
# 1608816  40.838309 -73.828930
# 1610213  40.813095 -73.898259
# 1610399        NaN        NaN
# 1610625  40.733373 -74.002573
# 1610834  40.757672 -73.994824
#
#                                                   LOCATION
# 7        {'type': 'Point', 'coordinates': [-73.91679, 4...  \
# 14       {'type': 'Point', 'coordinates': [-73.81422, 4...
# 111      {'type': 'Point', 'coordinates': [-74.157234, ...
# 190      {'type': 'Point', 'coordinates': [-73.912964, ...
# 219      {'type': 'Point', 'coordinates': [-73.92251, 4...
# ...                                                    ...
# 1608816  {'type': 'Point', 'coordinates': [-73.82893, 4...
# 1610213  {'type': 'Point', 'coordinates': [-73.8982589,...
# 1610399                                                NaN
# 1610625  {'type': 'Point', 'coordinates': [-74.0025727,...
# 1610834  {'type': 'Point', 'coordinates': [-73.9948239,...
#
#                            ON STREET NAME                 CROSS STREET NAME
# 7        MAJOR DEEGAN EXPRESSWAY                                        NaN  \
# 14                                    NaN                               NaN
# 111                                   NaN                               NaN
# 190      EAST 149 STREET                                                NaN
# 219      VERMILYEA AVENUE                                               NaN
# ...                                   ...                               ...
# 1608816  CROSBY AVENUE                     WATERBURY AVENUE
# 1610213  BRUCKNER BOULEVARD                LEGGETT AVENUE
# 1610399  BRUCKNER BOULEVARD                EAST 135 STREET
# 1610625  GROVE STREET                      WEST 4 STREET
# 1610834  WEST 40 STREET                    DYER AVENUE
#
#                                   OFF STREET NAME  ...
# 7                                             NaN  ...  \
# 14       125-05    115 AVENUE                      ...
# 111      4514      HYLAN BOULEVARD                 ...
# 190                                           NaN  ...
# 219                                           NaN  ...
# ...                                           ...  ...
# 1608816                                       NaN  ...
# 1610213                                       NaN  ...
# 1610399                                       NaN  ...
# 1610625                                       NaN  ...
# 1610834                                       NaN  ...
#
#           CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3
# 7                           Unspecified                            NaN  \
# 14                         Unsafe Speed                            NaN
# 111                         Unspecified                            NaN
# 190                         Unspecified                            NaN
# 219      Driver Inattention/Distraction                    Unspecified
# ...                                 ...                            ...
# 1608816                     Unspecified                    Unspecified
# 1610213                             NaN                            NaN
# 1610399                     Unspecified                    Unspecified
# 1610625                     Unspecified                            NaN
# 1610834                     Unspecified                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5
# 7                                  NaN                            NaN  \
# 14                                 NaN                            NaN
# 111                                NaN                            NaN
# 190                                NaN                            NaN
# 219                        Unspecified                            NaN
# ...                                ...                            ...
# 1608816                            NaN                            NaN
# 1610213                            NaN                            NaN
# 1610399                            NaN                            NaN
# 1610625                            NaN                            NaN
# 1610834                            NaN                            NaN
#
#          COLLISION_ID                  VEHICLE TYPE CODE 1
# 7             4187134                           Motorcycle  \
# 14            4187599  Station Wagon/Sport Utility Vehicle
# 111           4187379  Station Wagon/Sport Utility Vehicle
# 190           4191503  Station Wagon/Sport Utility Vehicle
# 219           4200221                           Motorcycle
# ...               ...                                  ...
# 1608816         88793                                OTHER
# 1610213         76272                    PASSENGER VEHICLE
# 1610399         72670                                  VAN
# 1610625          9399                                  VAN
# 1610834         16696        SPORT UTILITY / STATION WAGON
#
#                          VEHICLE TYPE CODE 2
# 7        Station Wagon/Sport Utility Vehicle  \
# 14                                     Sedan
# 111      Station Wagon/Sport Utility Vehicle
# 190                                    Sedan
# 219                                    Sedan
# ...                                      ...
# 1608816                    PASSENGER VEHICLE
# 1610213                                  NaN
# 1610399        SPORT UTILITY / STATION WAGON
# 1610625                    PASSENGER VEHICLE
# 1610834        SPORT UTILITY / STATION WAGON
#
#                          VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4
# 7                                        NaN                 NaN  \
# 14                                       NaN                 NaN
# 111                                      NaN                 NaN
# 190                                      NaN                 NaN
# 219      Station Wagon/Sport Utility Vehicle           Box Truck
# ...                                      ...                 ...
# 1608816                    PASSENGER VEHICLE                 NaN
# 1610213                                  NaN                 NaN
# 1610399              SMALL COM VEH(4 TIRES)                  NaN
# 1610625                                  NaN                 NaN
# 1610834                                  NaN                 NaN
#
#         VEHICLE TYPE CODE 5
# 7                       NaN
# 14                      NaN
# 111                     NaN
# 190                     NaN
# 219                     NaN
# ...                     ...
# 1608816                 NaN
# 1610213                 NaN
# 1610399                 NaN
# 1610625                 NaN
# 1610834                 NaN
#
# [15910 rows x 29 columns]

# %% [markdown]
# Wybrane kolumny danych

# %%
Unsafe_speed_selectes_data_columns = Unsafe_speed_selectes_data[['BOROUGH','NUMBER OF PERSONS INJURED','NUMBER OF PERSONS KILLED','CONTRIBUTING FACTOR VEHICLE 1','CONTRIBUTING FACTOR VEHICLE 2','CONTRIBUTING FACTOR VEHICLE 3','CONTRIBUTING FACTOR VEHICLE 4','CONTRIBUTING FACTOR VEHICLE 5']]
Unsafe_speed_selectes_data_columns
# Out:
#                BOROUGH  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED
# 7                  NaN                        0.0                       1.0  \
# 14              QUEENS                        1.0                       0.0
# 111      STATEN ISLAND                        2.0                       0.0
# 190                NaN                        2.0                       0.0
# 219                NaN                        1.0                       0.0
# ...                ...                        ...                       ...
# 1608816          BRONX                        0.0                       0.0
# 1610213          BRONX                        1.0                       0.0
# 1610399            NaN                        0.0                       0.0
# 1610625      MANHATTAN                        0.0                       0.0
# 1610834      MANHATTAN                        0.0                       0.0
#
#         CONTRIBUTING FACTOR VEHICLE 1   CONTRIBUTING FACTOR VEHICLE 2
# 7                        Unsafe Speed                     Unspecified  \
# 14            View Obstructed/Limited                    Unsafe Speed
# 111                      Unsafe Speed                     Unspecified
# 190                      Unsafe Speed                     Unspecified
# 219                      Unsafe Speed  Driver Inattention/Distraction
# ...                               ...                             ...
# 1608816                  Unsafe Speed                     Unspecified
# 1610213                  Unsafe Speed                             NaN
# 1610399                  Unsafe Speed                     Unspecified
# 1610625                  Unsafe Speed                     Unspecified
# 1610834                  Unsafe Speed                     Unspecified
#
#         CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4
# 7                                 NaN                           NaN  \
# 14                                NaN                           NaN
# 111                               NaN                           NaN
# 190                               NaN                           NaN
# 219                       Unspecified                   Unspecified
# ...                               ...                           ...
# 1608816                   Unspecified                           NaN
# 1610213                           NaN                           NaN
# 1610399                   Unspecified                           NaN
# 1610625                           NaN                           NaN
# 1610834                           NaN                           NaN
#
#         CONTRIBUTING FACTOR VEHICLE 5
# 7                                 NaN
# 14                                NaN
# 111                               NaN
# 190                               NaN
# 219                               NaN
# ...                               ...
# 1608816                           NaN
# 1610213                           NaN
# 1610399                           NaN
# 1610625                           NaN
# 1610834                           NaN
#
# [15910 rows x 8 columns]

# %%
Unsafe_speed_missing_data = Unsafe_speed_selectes_data_columns.copy()
Unsafe_speed_missing_data['BOROUGH'] = Unsafe_speed_selectes_data_columns['BOROUGH'].fillna('UNDEFINIED')
Unsafe_speed_missing_data
# Out:
#                BOROUGH  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED
# 7           Undefinied                        0.0                       1.0  \
# 14              QUEENS                        1.0                       0.0
# 111      STATEN ISLAND                        2.0                       0.0
# 190         Undefinied                        2.0                       0.0
# 219         Undefinied                        1.0                       0.0
# ...                ...                        ...                       ...
# 1608816          BRONX                        0.0                       0.0
# 1610213          BRONX                        1.0                       0.0
# 1610399     Undefinied                        0.0                       0.0
# 1610625      MANHATTAN                        0.0                       0.0
# 1610834      MANHATTAN                        0.0                       0.0
#
#         CONTRIBUTING FACTOR VEHICLE 1   CONTRIBUTING FACTOR VEHICLE 2
# 7                        Unsafe Speed                     Unspecified  \
# 14            View Obstructed/Limited                    Unsafe Speed
# 111                      Unsafe Speed                     Unspecified
# 190                      Unsafe Speed                     Unspecified
# 219                      Unsafe Speed  Driver Inattention/Distraction
# ...                               ...                             ...
# 1608816                  Unsafe Speed                     Unspecified
# 1610213                  Unsafe Speed                             NaN
# 1610399                  Unsafe Speed                     Unspecified
# 1610625                  Unsafe Speed                     Unspecified
# 1610834                  Unsafe Speed                     Unspecified
#
#         CONTRIBUTING FACTOR VEHICLE 3 CONTRIBUTING FACTOR VEHICLE 4
# 7                                 NaN                           NaN  \
# 14                                NaN                           NaN
# 111                               NaN                           NaN
# 190                               NaN                           NaN
# 219                       Unspecified                   Unspecified
# ...                               ...                           ...
# 1608816                   Unspecified                           NaN
# 1610213                           NaN                           NaN
# 1610399                   Unspecified                           NaN
# 1610625                           NaN                           NaN
# 1610834                           NaN                           NaN
#
#         CONTRIBUTING FACTOR VEHICLE 5
# 7                                 NaN
# 14                                NaN
# 111                               NaN
# 190                               NaN
# 219                               NaN
# ...                               ...
# 1608816                           NaN
# 1610213                           NaN
# 1610399                           NaN
# 1610625                           NaN
# 1610834                           NaN
#
# [15910 rows x 8 columns]

# %%
sum_data_injured_killed = Unsafe_speed_missing_data.groupby('BOROUGH').agg({"NUMBER OF PERSONS INJURED": "sum", 
                                                        "NUMBER OF PERSONS KILLED": 'sum'})
sum_data_injured_killed
# Out:
#                NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED
# BOROUGH
# BRONX                             1103.0                       5.0
# BROOKLYN                          1804.0                      19.0
# MANHATTAN                          491.0                       3.0
# QUEENS                            1470.0                      28.0
# STATEN ISLAND                      279.0                       2.0
# Undefinied                        4932.0                      96.0

# %%
sum_data_injured = sum_data_injured_killed
sum_data_injured = sum_data_injured_killed['NUMBER OF PERSONS INJURED'].sum()
sum_data_injured
# Out:
# 10079.0

# %%
sum_data_killed = sum_data_injured_killed
sum_data_killed = sum_data_injured_killed['NUMBER OF PERSONS KILLED'].sum()
sum_data_killed
# Out:
# 153.0
